# %% [markdown]
# <a href="https://colab.research.google.com/github/sonjoy1s/CNN_learn/blob/main/CNN_module25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from PIL import Image

# %%
image = Image.open('/content/photo-1566669086984-077347c1f4bb.avif')
plt.imshow(image)
